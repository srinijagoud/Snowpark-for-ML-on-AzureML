# %% [markdown]
# CONNECT

# %%
# for a quicker set up ignore the step in the quickstart where you create a Snowflake environment, uncomment the below code and install the libraries provided
# there may be some errors about the datasets package but the lab should still run regardless
# %pip install snowflake pandas notebook scikit-learn cachetools pyarrow==10.0.1 snowflake-ml-python

# %%
# %pip install "snowflake-connector-python[pandas]>=3.17.0,<5.0.0"
# Out:
# Collecting snowflake-connector-python<5.0.0,>=3.17.0 (from snowflake-connector-python[pandas]<5.0.0,>=3.17.0)
#   Using cached snowflake_connector_python-4.7.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (96 kB)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /anaconda/envs/my_env/lib/python3.11/site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (1.5.1)
# Collecting cryptography>=46.0.5 (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0)
#   Downloading cryptography-50.0.1-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: pyOpenSSL>=24.0.0 in /anaconda/envs/my_env/lib/python3.11/site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (25.3.0)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /anaconda/envs/my_env/lib/python3.11/site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (2.13.0)
# Requirement already satisfied: pytz in /anaconda/envs/my_env/lib/python3.11/site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (2026.3.post1)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /anaconda/envs/my_env/lib/python3.11/site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (2.34.2)
# Requirement already satisfied: packaging in /anaconda/envs/my_env/lib/python3.11/site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (26.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /anaconda/envs/my_env/lib/python3.11/site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (3.5.1)
# Requirement already satisfied: idna<4,>=3.7 in /anaconda/envs/my_env/lib/python3.11/site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (3.19)
# Requirement already satisfied: certifi>=2024.7.4 in /anaconda/envs/my_env/lib/python3.11/site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (2026.7.22)
# Requirement already satisfied: typing_extensions<5,>=4.3 in /anaconda/envs/my_env/lib/python3.11/site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (4.16.0)
# Requirement already satisfied: filelock<4,>=3.5 in /anaconda/envs/my_env/lib/python3.11/site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (3.32.5)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /anaconda/envs/my_env/lib/python3.11/site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in /anaconda/envs/my_env/lib/python3.11/site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (4.11.6)
# Requirement already satisfied: tomlkit in /anaconda/envs/my_env/lib/python3.11/site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (0.15.1)
# Requirement already satisfied: boto3>=1.24 in /anaconda/envs/my_env/lib/python3.11/site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (1.43.88)
# Requirement already satisfied: botocore>=1.24 in /anaconda/envs/my_env/lib/python3.11/site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (1.43.88)
# Requirement already satisfied: urllib3<3,>=1.26 in /anaconda/envs/my_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.4->snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (2.7.0)
# Requirement already satisfied: pandas<3.0.0,>=1.0.0 in /anaconda/envs/my_env/lib/python3.11/site-packages (from snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (1.5.3)
# Collecting pyarrow>=14.0.1 (from snowflake-connector-python[pandas]<5.0.0,>=3.17.0)
#   Downloading pyarrow-25.0.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /anaconda/envs/my_env/lib/python3.11/site-packages (from pandas<3.0.0,>=1.0.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.21.0 in /anaconda/envs/my_env/lib/python3.11/site-packages (from pandas<3.0.0,>=1.0.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (2.4.6)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /anaconda/envs/my_env/lib/python3.11/site-packages (from boto3>=1.24->snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (1.1.0)
# Requirement already satisfied: s3transfer<0.20.0,>=0.19.0 in /anaconda/envs/my_env/lib/python3.11/site-packages (from boto3>=1.24->snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (0.19.2)
# Requirement already satisfied: six>=1.5 in /anaconda/envs/my_env/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas<3.0.0,>=1.0.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (1.17.0)
# Collecting cffi>=2.0.0 (from cryptography>=46.0.5->snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0)
#   Downloading cffi-2.1.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.5 kB)
# Requirement already satisfied: pycparser in /anaconda/envs/my_env/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography>=46.0.5->snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0) (3.0)
# Collecting cryptography>=46.0.5 (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-connector-python[pandas]<5.0.0,>=3.17.0)
#   Using cached cryptography-46.0.7-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (5.7 kB)
# Downloading snowflake_connector_python-4.7.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 48.8 MB/s  0:00:00
# Downloading cffi-2.1.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (217 kB)
# Downloading pyarrow-25.0.1-cp311-cp311-manylinux_2_28_x86_64.whl (50.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 MB 99.5 MB/s  0:00:006m0:00:0100:01
# Downloading cryptography-46.0.7-cp311-abi3-manylinux_2_34_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 131.0 MB/s  0:00:00
# Installing collected packages: pyarrow, cffi, cryptography, snowflake-connector-python
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 10.0.1
#     Uninstalling pyarrow-10.0.1:
#       Successfully uninstalled pyarrow-10.0.1
#   Attempting uninstall: cffi━━━━━━━━━━━━━━━━━━━━ 0/4 [pyarrow]
#     Found existing installation: cffi 1.17.1 0/4 [pyarrow]
#     Uninstalling cffi-1.17.1:━━━━━━━━━━━━━━━ 0/4 [pyarrow]
#       Successfully uninstalled cffi-1.17.1━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [cffi]
#   Attempting uninstall: cryptographym━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [cffi]
#     Found existing installation: cryptography 46.0.0━━━━━━━━━━ 1/4 [cffi]
#     Uninstalling cryptography-46.0.0:━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [cffi]
#       Successfully uninstalled cryptography-46.0.0━━━━━━━━━━━━ 1/4 [cffi]
#   Attempting uninstall: snowflake-connector-python━━━━━━━━━━━━━━━━ 2/4 [cryptography]
#     Found existing installation: snowflake-connector-python 3.14.0 2/4 [cryptography]
#     Uninstalling snowflake-connector-python-3.14.0:━━━━━━━━━━━ 2/4 [cryptography]
#       Successfully uninstalled snowflake-connector-python-3.14.00m 2/4 [cryptography]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [snowflake-connector-python]-connector-python]
# Successfully installed cffi-2.1.1 cryptography-46.0.7 pyarrow-25.0.1 snowflake-connector-python-4.7.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install "numpy<2.0.0,>=1.23.5"
# Out:
# Collecting numpy<2.0.0,>=1.23.5
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 56.1 MB/s  0:00:00eta 0:00:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.6
#     Uninstalling numpy-2.4.6:
#       Successfully uninstalled numpy-2.4.6
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from snowflake.snowpark import Session
from snowflake.snowpark.functions import *
from snowflake.snowpark.types import *

connection_parameters = {
    "account": "MF72391",
    "user": "SRIJA", 
    "host": "TLSOURR-MF72391.snowflakecomputing.com", # e.g. "sn00111.snowflakecomputing.com",
    "password": "Srijastar@1234",
    "role": "ACCOUNTADMIN",
    "warehouse": "SMALL_WH",
    "database":"HOL_DB",
    "schema":"PUBLIC"
    }
session = Session.builder.configs(connection_parameters).create()

# %%
# Loading from local CSV-files
city_udi_df = pd.read_csv('city_udi.csv')
humidity_df = pd.read_csv('humidity.csv')
maintenance_df = pd.read_csv('maintenance.csv')

# %% [markdown]
# LOAD

# %%
session.sql("SHOW WAREHOUSES").show()
# Out:
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"name"                        |"state"    |"type"    |"size"   |"min_cluster_count"  |"max_cluster_count"  |"started_clusters"  |"running"  |"queued"  |"is_default"  |"is_current"  |"auto_suspend"  |"auto_resume"  |"available"  |"provisioning"  |"quiescing"  |"other"  |"created_on"                      |"resumed_on"                      |"updated_on"                      |"owner"       |"comment"                                         |"enable_query_acceleration"  |"query_acceleration_max_scale_factor"  |"resource_monitor"  |"actives"  |"pendings"  |"failed"  |"suspended"  |"uuid"     |"scaling_policy"  |"owner_role_type"  |"resource_constraint"  |"generation"  |"query_throughput_multiplier"  |"max_query_performance_level"  |"disabled_reasons"  |"tables"  |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |COMPUTE_WH                    |SUSPENDED  |STANDARD  |X-Small  |1                    |1                    |0                   |0          |0         |Y             |N             |300             |true           |             |                |             |         |2026-09-05 18:08:03.885000-07:00  |2026-09-06 07:44:47.546000-07:00  |2026-09-06 07:44:47.546000-07:00  |ACCOUNTADMIN  |                                                  |true                         |2                                      |null                |0          |0           |0         |1            |136906324  |STANDARD          |ROLE               |STANDARD_GEN_2         |2             |NULL                           |NULL                           |NULL                |NULL      |
# |SNOWFLAKE_LEARNING_WH         |SUSPENDED  |STANDARD  |X-Small  |1                    |1                    |0                   |0          |0         |N             |N             |300             |true           |             |                |             |         |2026-09-05 18:05:28.557000-07:00  |2026-09-05 18:05:28.557000-07:00  |2026-09-05 18:05:28.566000-07:00  |ACCOUNTADMIN  |Created by Snowflake during account provisioning  |true                         |2                                      |null                |0          |0           |0         |1            |136906252  |STANDARD          |ROLE               |STANDARD_GEN_2         |2             |NULL                           |NULL                           |NULL                |NULL      |
# |SYSTEM$STREAMLIT_NOTEBOOK_WH  |SUSPENDED  |STANDARD  |X-Small  |1                    |10                   |0                   |0          |0         |N             |N             |60              |true           |             |                |             |         |2026-09-05 18:05:26.970000-07:00  |2026-09-05 18:05:26.980000-07:00  |2026-09-05 18:05:27.002000-07:00  |ACCOUNTADMIN  |                                                  |true                         |2                                      |null                |0          |0           |0         |1            |136906244  |STANDARD          |ROLE               |STANDARD_GEN_2         |2             |NULL                           |NULL                           |NULL                |NULL      |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
#session.use_role("ACCOUNTADMIN")
session.use_warehouse("COMPUTE_WH")

# %%
# Upload to Snowflake
session.write_pandas(city_udi_df, table_name='CITY_UDF', auto_create_table=True, overwrite=True)
session.write_pandas(humidity_df, table_name='HUMIDITY', auto_create_table=True, overwrite=True)
session.write_pandas(maintenance_df, table_name='MAINTENANCE', auto_create_table=True, overwrite=True)

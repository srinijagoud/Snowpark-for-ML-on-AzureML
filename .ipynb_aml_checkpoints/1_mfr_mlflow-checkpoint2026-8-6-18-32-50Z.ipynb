# %% [markdown]
# # Connect to Snowflake

# %%
# access data from snowflake
import pandas as pd
from snowflake.snowpark.session import Session
from snowflake.snowpark.functions import *
from snowflake.snowpark.types import *

connection_parameters = {
    "account": "MF72391",
    "user": "SRIJA", 
    "host": "TLSOURR-MF72391.snowflakecomputing.com", # e.g. "sn00111.snowflakecomputing.com",
    "password": "Srijastar@1234",
    "role": "ACCOUNTADMIN",
    "warehouse": "SMALL_WH",
    "database":"HOL_DB",
    "schema":"PUBLIC"
    }
session = Session.builder.configs(connection_parameters).create()

maintenance_df = session.table('HOL_DB.PUBLIC.maintenance')
humidity_df = session.table('HOL_DB.PUBLIC.Humidity')
city_df = session.table('HOL_DB.PUBLIC.CITY_UDF')

# %% [markdown]
# # Look at the dataframes

# %%
maintenance_df.to_pandas().head()
# Out:
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 maintenance_df.to_pandas().head()
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/telemetry.py:297, in df_collect_api_telemetry.<locals>.wrap(*args, **kwargs)
#     295 try:
#     296     with ResourceUsageCollector() as resource_usage_collector:
# --> 297         result = func(*args, **kwargs)
#     298     resource_usage = resource_usage_collector.get_resource_usage()
#     299 finally:
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/utils.py:1215, in publicapi.<locals>.call_wrapper(*args, **kwargs)
#    1211 kwargs["_emit_ast"] = is_ast_enabled()
#    1213 # TODO: Could modify internal docstring to display that users should not modify the _emit_ast parameter.
# -> 1215 return func(*args, **kwargs)
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/dataframe.py:1156, in DataFrame.to_pandas(self, statement_params, block, _emit_ast, **kwargs)
#    1153     _, kwargs[DATAFRAME_AST_PARAMETER] = self._session._ast_batch.flush(stmt)
#    1155 with open_telemetry_context_manager(self.to_pandas, self):
# -> 1156     result = self._session._conn.execute(
#    1157         self._plan,
#    1158         to_pandas=True,
#    1159         block=block,
#    1160         data_type=_AsyncResultType.PANDAS,
#    1161         _statement_params=create_or_update_statement_params_with_query_tag(
#    1162             statement_params or self._statement_params,
#    1163             self._session.query_tag,
#    1164             SKIP_LEVELS_TWO,
#    1165             collect_stacktrace=self._session.conf.get(
#    1166                 "collect_stacktrace_in_query_tag"
#    1167             ),
#    1168         ),
#    1169         **kwargs,
#    1170     )
#    1172 if block:
#    1173     if not isinstance(result, pandas.DataFrame):
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:649, in ServerConnection.execute(self, plan, to_pandas, to_iter, to_arrow, block, data_type, log_on_exception, case_sensitive, **kwargs)
#     639 if (
#     640     is_in_stored_procedure()
#     641     and not block
#    (...)    644     )
#     645 ):  # pragma: no cover
#     646     raise NotImplementedError(
#     647         "Async query is not supported in stored procedure yet"
#     648     )
# --> 649 result_set, result_meta = self.get_result_set(
#     650     plan,
#     651     to_pandas,
#     652     to_iter,
#     653     **kwargs,
#     654     block=block,
#     655     data_type=data_type,
#     656     log_on_exception=log_on_exception,
#     657     case_sensitive=case_sensitive,
#     658     to_arrow=to_arrow,
#     659 )
#     660 if not block:
#     661     return result_set
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:421, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     416                 raise ne.with_traceback(tb) from None
#     418 ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     419     e, debug_context=debug_context
#     420 )
# --> 421 raise ne.with_traceback(tb) from None
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:174, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     168 from snowflake.snowpark.context import (
#     169     _enable_dataframe_trace_on_error,
#     170     _enable_trace_sql_errors_to_dataframe,
#     171 )
#     173 try:
# --> 174     return func(*args, **kwargs)
#     175 except snowflake.connector.errors.ProgrammingError as e:
#     176     from snowflake.snowpark._internal.analyzer.select_statement import (
#     177         Selectable,
#     178     )
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:715, in ServerConnection.get_result_set(self, plan, to_pandas, to_iter, block, data_type, log_on_exception, case_sensitive, ignore_results, to_arrow, **kwargs)
#     708 should_retry_without_cte = (
#     709     block  # Snowpark Connect does not use async queries. Async queries retry tracked by SNOW-3293313
#     710     and context._is_snowpark_connect_compatible_mode
#     711     and session.cte_optimization_enabled
#     712 )
#     714 try:
# --> 715     result, result_meta = self._execute_queries(
#     716         plan,
#     717         plan_queries,
#     718         action_id,
#     719         to_pandas=to_pandas,
#     720         to_iter=to_iter,
#     721         block=block,
#     722         data_type=data_type,
#     723         log_on_exception=log_on_exception,
#     724         case_sensitive=case_sensitive,
#     725         ignore_results=ignore_results,
#     726         to_arrow=to_arrow,
#     727         **kwargs,
#     728     )
#     729 except ProgrammingError as cte_error:
#     730     if not should_retry_without_cte:
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:898, in ServerConnection._execute_queries(self, plan, plan_queries, action_id, to_pandas, to_iter, block, data_type, log_on_exception, case_sensitive, ignore_results, to_arrow, **kwargs)
#     896     kwargs[DATAFRAME_AST_PARAMETER] = dataframe_ast
#     897 is_final_query = i == len(main_queries) - 1
# --> 898 result = self.run_query(
#     899     final_query,
#     900     to_pandas,
#     901     to_iter and is_final_query,
#     902     is_ddl_on_temp_object=query.is_ddl_on_temp_object,
#     903     block=not is_last,
#     904     data_type=data_type,
#     905     async_job_plan=plan,
#     906     log_on_exception=log_on_exception,
#     907     case_sensitive=case_sensitive,
#     908     params=query.params,
#     909     ignore_results=ignore_results,
#     910     async_post_actions=post_actions,
#     911     to_arrow=to_arrow and is_final_query,
#     912     **kwargs,
#     913 )
#     914 placeholders[query.query_id_place_holder] = (
#     915     result["sfqid"] if not is_last else result.query_id
#     916 )
#     917 result_meta = get_new_description(self._cursor)
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:138, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     134     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     135         ex.cause
#     136     )
#     137 except Exception as ex:
# --> 138     raise ex
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:132, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     130     raise SnowparkClientExceptionMessages.SERVER_SESSION_HAS_BEEN_CLOSED()
#     131 try:
# --> 132     return func(*args, **kwargs)
#     133 except ReauthenticationRequest as ex:
#     134     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     135         ex.cause
#     136     )
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:545, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, log_on_exception, case_sensitive, params, num_statements, ignore_results, async_post_actions, to_arrow, **kwargs)
#     543         query_id_log = f" [queryID: {ex.sfqid}]" if hasattr(ex, "sfqid") else ""
#     544         logger.error(f"Failed to execute query{query_id_log} {query}\n{ex}")
# --> 545     raise ex
#     547 # fetch_pandas_all/batches() only works for SELECT statements
#     548 # We call fetchall() if fetch_pandas_all/batches() fails,
#     549 # because when the query plan has multiple queries, it will
#     550 # have non-select statements, and it shouldn't fail if the user
#     551 # calls to_pandas() to execute the query.
#     552 if block:
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:530, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, log_on_exception, case_sensitive, params, num_statements, ignore_results, async_post_actions, to_arrow, **kwargs)
#     528     cached_analyze_attributes.clear_cache()
#     529 if block:
# --> 530     results_cursor = self.execute_and_notify_query_listener(
#     531         query, params=params, **kwargs
#     532     )
#     533     logger.debug(f"Execute query [queryID: {results_cursor.sfqid}] {query}")
#     534 else:
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:460, in ServerConnection.execute_and_notify_query_listener(self, query, **kwargs)
#     456     err_query = ex.query if isinstance(ex, Error) else query
#     457     self.notify_query_listeners(
#     458         QueryRecord(sfqid, err_query, False), is_error=True, **notify_kwargs
#     459     )
# --> 460     raise ex
#     462 notify_kwargs["requestId"] = str(results_cursor._request_id)
#     463 self.notify_query_listeners(
#     464     QueryRecord(results_cursor.sfqid, results_cursor.query), **notify_kwargs
#     465 )
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:451, in ServerConnection.execute_and_notify_query_listener(self, query, **kwargs)
#     449         notify_kwargs["dataframe_uuid"] = statement_params["_PLAN_UUID"]
#     450 try:
# --> 451     results_cursor = self._cursor.execute(query, **kwargs)
#     452 except Exception as ex:
#     453     notify_kwargs["requestId"] = None
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/connector/cursor.py:1142, in SnowflakeCursorBase.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements, _force_qmark_paramstyle, _dataframe_ast)
#    1138     is_integrity_error = (
#    1139         code == "100072"
#    1140     )  # NULL result in a non-nullable column
#    1141     error_class = IntegrityError if is_integrity_error else ProgrammingError
# -> 1142     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#    1143 return self
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/connector/errors.py:298, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     275 @staticmethod
#     276 def errorhandler_wrapper(
#     277     connection: SnowflakeConnection | None,
#    (...)    280     error_value: dict[str, Any],
#     281 ) -> None:
#     282     """Error handler wrapper that calls the errorhandler method.
#     283
#     284     Args:
#    (...)    295         exception to the first handler in that order.
#     296     """
# --> 298     handed_over = Error.hand_to_other_handler(
#     299         connection,
#     300         cursor,
#     301         error_class,
#     302         error_value,
#     303     )
#     304     if not handed_over:
#     305         raise Error.errorhandler_make_exception(
#     306             error_class,
#     307             error_value,
#     308         )
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/connector/errors.py:354, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     352 cursor.messages.append((error_class, error_value))
#     353 try:
# --> 354     cursor.errorhandler(connection, cursor, error_class, error_value)
#     355 except NotImplementedError:
#     356     # for async compatibility, check SNOW-1763096 and SNOW-1763103
#     357     cursor._errorhandler(connection, cursor, error_class, error_value)
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/connector/errors.py:229, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     227 errno = error_value.get("errno")
#     228 done_format_msg = error_value.get("done_format_msg")
# --> 229 raise error_class(
#     230     msg=error_value.get("msg"),
#     231     errno=None if errno is None else int(errno),
#     232     sqlstate=error_value.get("sqlstate"),
#     233     sfqid=error_value.get("sfqid"),
#     234     query=error_value.get("query"),
#     235     done_format_msg=(
#     236         None if done_format_msg is None else bool(done_format_msg)
#     237     ),
#     238     connection=connection,
#     239     cursor=cursor,
#     240 )
#
# SnowparkSQLException: (1304): 01c6e4aa-3204-801a-0008-29060001c84a: 002003 (42S02): SQL compilation error:
# Object 'HOL_DB.PUBLIC.MAINTENANCE' does not exist or not authorized.

# %%
humidity_df.to_pandas().head()

# %%
city_df.to_pandas().head()

# %%
# join together the dataframes and prepare training dataset
maintenance_city = maintenance_df.join(city_df, ["UDI"])
maintenance_hum = maintenance_city.join(humidity_df, (maintenance_city.col("CITY") == humidity_df.col("CITY_NAME"))).select(col("TYPE"), 
col("AIR_TEMPERATURE_K"), col("PROCESS_TEMPERATURE"), col("ROTATIONAL_SPEED_RPM"), col("TORQUE_NM"), col("TOOL_WEAR_MIN"), col("HUMIDITY_RELATIVE_AVG"), col("MACHINE_FAILURE"))
# Out:
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# Cell In[3], line 2
#       1 # join together the dataframes and prepare training dataset
# ----> 2 maintenance_city = maintenance_df.join(city_df, ["UDI"])
#       3 maintenance_hum = maintenance_city.join(humidity_df, (maintenance_city.col("CITY") == humidity_df.col("CITY_NAME"))).select(col("TYPE"),
#       4 col("AIR_TEMPERATURE_K"), col("PROCESS_TEMPERATURE"), col("ROTATIONAL_SPEED_RPM"), col("TORQUE_NM"), col("TOOL_WEAR_MIN"), col("HUMIDITY_RELATIVE_AVG"), col("MACHINE_FAILURE"))
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/telemetry.py:376, in df_api_usage.<locals>.wrap(*args, **kwargs)
#     373 @functools.wraps(func)
#     374 def wrap(*args, **kwargs):
#     375     with ResourceUsageCollector() as resource_usage_collector:
# --> 376         r = func(*args, **kwargs)
#     377     plan = r._select_statement or r._plan
#     378     # Some DataFrame APIs call other DataFrame APIs, so we need to remove the extra call
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/utils.py:1215, in publicapi.<locals>.call_wrapper(*args, **kwargs)
#    1211 kwargs["_emit_ast"] = is_ast_enabled()
#    1213 # TODO: Could modify internal docstring to display that users should not modify the _emit_ast parameter.
# -> 1215 return func(*args, **kwargs)
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/dataframe.py:4058, in DataFrame.join(self, right, on, how, lsuffix, rsuffix, match_condition, directed, _emit_ast, **kwargs)
#    4055         if rsuffix:
#    4056             ast.rsuffix.value = rsuffix
# -> 4058     return self._join_dataframes(
#    4059         right,
#    4060         using_columns,
#    4061         join_type,
#    4062         lsuffix=lsuffix,
#    4063         rsuffix=rsuffix,
#    4064         match_condition=match_condition,
#    4065         directed=directed,
#    4066         _ast_stmt=stmt,
#    4067     )
#    4069 raise TypeError("Invalid type for join. Must be Dataframe")
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/dataframe.py:4352, in DataFrame._join_dataframes(self, right, using_columns, join_type, lsuffix, rsuffix, match_condition, directed, _ast_stmt)
#    4342     return self._join_dataframes_internal(
#    4343         right,
#    4344         join_type,
#    (...)   4349         _ast_stmt=_ast_stmt,
#    4350     )
#    4351 else:
# -> 4352     lhs, rhs = _disambiguate(
#    4353         self,
#    4354         right,
#    4355         join_type,
#    4356         using_columns,
#    4357         lsuffix=lsuffix,
#    4358         rsuffix=rsuffix,
#    4359     )
#    4360     if not isinstance(
#    4361         join_type, Cross
#    4362     ):  # cross joins does not allow specifying columns
#    4363         join_type = UsingJoin(join_type, using_columns)
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/dataframe.py:360, in _disambiguate(lhs, rhs, join_type, using_columns, lsuffix, rsuffix)
#     355 normalized_using_columns = {quote_name(c) for c in using_columns}
#     356 #  Check if the LHS and RHS have columns in common. If they don't just return them as-is. If
#     357 #  they do have columns in common, alias the common columns with randomly generated l_
#     358 #  and r_ prefixes for the left and right sides respectively.
#     359 #  We assume the column names from the schema are normalized and quoted.
# --> 360 lhs_names = [attr.name for attr in lhs._output]
#     361 rhs_names = [attr.name for attr in rhs._output]
#     362 common_col_names = [
#     363     n
#     364     for n in lhs_names
#     365     if n in set(rhs_names) and n not in normalized_using_columns
#     366 ]
#
# File /anaconda/envs/my_env/lib/python3.11/functools.py:1001, in cached_property.__get__(self, instance, owner)
#     999 val = cache.get(self.attrname, _NOT_FOUND)
#    1000 if val is _NOT_FOUND:
# -> 1001     val = self.func(instance)
#    1002     try:
#    1003         cache[self.attrname] = val
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/dataframe.py:6820, in DataFrame._output(self)
#    6817 @cached_property
#    6818 def _output(self) -> List[Attribute]:
#    6819     return (
# -> 6820         self._select_statement.column_states.projection
#    6821         if self._select_statement
#    6822         else self._plan.output
#    6823     )
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/select_statement.py:1037, in SelectStatement.column_states(self)
#    1035 if self._column_states is None:
#    1036     if not self.has_projection and not self.has_clause:
# -> 1037         self.column_states = self.from_.column_states
#    1038     else:
#    1039         super().column_states  # will assign value to self._column_states
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/select_statement.py:495, in Selectable.column_states(self)
#     490         column_attrs = [
#     491             Attribute(q, DataType())
#     492             for q in self.snowflake_plan.quoted_identifiers
#     493         ]
#     494     else:
# --> 495         column_attrs = self.snowflake_plan.attributes
#     496     self._column_states = initiate_column_states(
#     497         column_attrs,
#     498         self.analyzer,
#     499         self.df_aliased_col_name_to_real_col_name,
#     500     )
#     501 return self._column_states
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:613, in SnowflakePlan.attributes(self)
#     609     return self._metadata.attributes
#     610 assert (
#     611     self.schema_query is not None
#     612 ), "No schema query is available for the SnowflakePlan"
# --> 613 attributes = self._analyze_attributes()
#     614 self._metadata = PlanMetadata(attributes=attributes, quoted_identifiers=None)
#     615 # We need to cache attributes on SelectStatement too because df._plan is not
#     616 # carried over to next SelectStatement (e.g., check the implementation of df.filter()).
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:421, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     416                 raise ne.with_traceback(tb) from None
#     418 ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     419     e, debug_context=debug_context
#     420 )
# --> 421 raise ne.with_traceback(tb) from None
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:174, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     168 from snowflake.snowpark.context import (
#     169     _enable_dataframe_trace_on_error,
#     170     _enable_trace_sql_errors_to_dataframe,
#     171 )
#     173 try:
# --> 174     return func(*args, **kwargs)
#     175 except snowflake.connector.errors.ProgrammingError as e:
#     176     from snowflake.snowpark._internal.analyzer.select_statement import (
#     177         Selectable,
#     178     )
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:602, in SnowflakePlan._analyze_attributes(self)
#     598     return cached_analyze_attributes(
#     599         self.schema_query, self.session, self.uuid, query_params
#     600     )
#     601 else:
# --> 602     return analyze_attributes(
#     603         self.schema_query, self.session, self.uuid, query_params
#     604     )
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/schema_utils.py:108, in analyze_attributes(sql, session, dataframe_uuid, query_params)
#     106 stack_trace = [frame.line for frame in stack] if len(stack) > 0 else None
#     107 with measure_time() as e2e_time:
# --> 108     attributes = session._get_result_attributes(sql, query_params)
#     109 session._conn._telemetry_client.send_describe_query_details(
#     110     session._session_id, sql, e2e_time(), stack_trace
#     111 )
#     112 if dataframe_uuid:
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/session.py:3205, in Session._get_result_attributes(self, query, query_params)
#    3202 def _get_result_attributes(
#    3203     self, query: str, query_params: Optional[Sequence[Any]] = None
#    3204 ) -> List[Attribute]:
# -> 3205     return self._conn.get_result_attributes(query, query_params)
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:278, in ServerConnection.get_result_attributes(self, query, query_params)
#     274 def get_result_attributes(
#     275     self, query: str, query_params: Optional[Sequence[Any]] = None
#     276 ) -> List[Attribute]:
#     277     return convert_result_meta_to_attribute(
# --> 278         self._run_new_describe(self._cursor, query, query_params=query_params),
#     279         self.max_string_size,
#     280     )
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:289, in ServerConnection._run_new_describe(self, cursor, query, query_params, **kwargs)
#     282 def _run_new_describe(
#     283     self,
#     284     cursor: SnowflakeCursor,
#    (...)    287     **kwargs: dict,
#     288 ) -> Union[List[ResultMetadata], List["ResultMetadataV2"]]:
# --> 289     result_metadata = run_new_describe(cursor, query, query_params)
#     291     with self._lock:
#     292         for listener in filter(
#     293             lambda listener: hasattr(listener, "include_describe")
#     294             and listener.include_describe,
#     295             self._query_listeners,
#     296         ):
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/schema_utils.py:177, in run_new_describe(cursor, query, query_params)
#     168 """Execute describe() on a cursor, returning the new metadata format if possible.
#     169
#     170 If an older connector is in use, this function falls back to the old metadata format.
#     171 """
#     173 # ResultMetadataV2 may not currently be a type, depending on the connector
#     174 # version, so the argument types are pyright ignored
#     175
#     176 # Pyright does not perform narrowing here
# --> 177 return cursor._describe_internal(query, params=query_params)
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/connector/cursor.py:1182, in SnowflakeCursorBase._describe_internal(self, *args, **kwargs)
#    1171 """Obtain the schema of the result without executing the query.
#    1172
#    1173 This function takes the same arguments as execute, please refer to that function
#    (...)   1179     The schema of the result, in the new result metadata format.
#    1180 """
#    1181 kwargs["_describe_only"] = kwargs["_is_internal"] = True
# -> 1182 self.execute(*args, **kwargs)
#    1183 return self._description
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/connector/cursor.py:1142, in SnowflakeCursorBase.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements, _force_qmark_paramstyle, _dataframe_ast)
#    1138     is_integrity_error = (
#    1139         code == "100072"
#    1140     )  # NULL result in a non-nullable column
#    1141     error_class = IntegrityError if is_integrity_error else ProgrammingError
# -> 1142     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#    1143 return self
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/connector/errors.py:298, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     275 @staticmethod
#     276 def errorhandler_wrapper(
#     277     connection: SnowflakeConnection | None,
#    (...)    280     error_value: dict[str, Any],
#     281 ) -> None:
#     282     """Error handler wrapper that calls the errorhandler method.
#     283
#     284     Args:
#    (...)    295         exception to the first handler in that order.
#     296     """
# --> 298     handed_over = Error.hand_to_other_handler(
#     299         connection,
#     300         cursor,
#     301         error_class,
#     302         error_value,
#     303     )
#     304     if not handed_over:
#     305         raise Error.errorhandler_make_exception(
#     306             error_class,
#     307             error_value,
#     308         )
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/connector/errors.py:354, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     352 cursor.messages.append((error_class, error_value))
#     353 try:
# --> 354     cursor.errorhandler(connection, cursor, error_class, error_value)
#     355 except NotImplementedError:
#     356     # for async compatibility, check SNOW-1763096 and SNOW-1763103
#     357     cursor._errorhandler(connection, cursor, error_class, error_value)
#
# File /anaconda/envs/my_env/lib/python3.11/site-packages/snowflake/connector/errors.py:229, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     227 errno = error_value.get("errno")
#     228 done_format_msg = error_value.get("done_format_msg")
# --> 229 raise error_class(
#     230     msg=error_value.get("msg"),
#     231     errno=None if errno is None else int(errno),
#     232     sqlstate=error_value.get("sqlstate"),
#     233     sfqid=error_value.get("sfqid"),
#     234     query=error_value.get("query"),
#     235     done_format_msg=(
#     236         None if done_format_msg is None else bool(done_format_msg)
#     237     ),
#     238     connection=connection,
#     239     cursor=cursor,
#     240 )
#
# SnowparkSQLException: (1304): 01c6e4be-3204-8088-0008-29060001ba62: 002003 (42S02): SQL compilation error:
# Object 'HOL_DB.PUBLIC.MAINTENANCE' does not exist or not authorized.

# %%
# write training set to snowflake and materialize the data frame into a pandas data frame
maintenance_hum.write.mode("overwrite").save_as_table("HOL_DB.PUBLIC.MAINTENANCE_HUM")
maintenance_hum_df = session.table('HOL_DB.PUBLIC.MAINTENANCE_HUM').to_pandas()

# %%
# drop column thats not needed
maintenance_hum_df = maintenance_hum_df.drop(columns=["TYPE"])

# %% [markdown]
# # Use MLFlow to track jobs and models

# %%
# set up experiment
import mlflow
mlflow.set_experiment(experiment_name="predictive-maintenance")

# %% [markdown]
# # Split data and train model with mlflow logging

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    maintenance_hum_df.drop("MACHINE_FAILURE", axis=1), maintenance_hum_df["MACHINE_FAILURE"], test_size=0.3
)

# %%
from sklearn.linear_model import LogisticRegression
mlflow.autolog()
model = LogisticRegression()

# %%
run = mlflow.start_run()

# %%
model.fit(X_train, y_train)

# %% [markdown]
# # Quick Model Metrics

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, recall_score

accuracy = accuracy_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# %%
print("Accuracy: %.2f%%" % (accuracy * 100.0))
print("Recall: %.2f%%" % (recall * 100.0))

# %%
mlflow.end_run()

# %%
run = mlflow.get_run(run.info.run_id)

# %% [markdown]
# # More model metrics

# %%
pd.DataFrame(data=[run.data.params], index=["Value"]).T

# %%
pd.DataFrame(data=[run.data.metrics], index=["Value"]).T

# %%
# evaluate model on test
from sklearn import metrics
from sklearn.metrics import roc_auc_score, roc_curve, RocCurveDisplay
import matplotlib.pyplot as plt
y_pred = model.predict_proba(X_test)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr, tpr)
display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc,
                                   estimator_name='example estimator')
display.plot()
plt.show()

# %%
# auc score
roc_auc_score(y_test, y_pred)

# %%
from sklearn.inspection import permutation_importance
feature_names = ['AIR_TEMPERATURE_K',
       'PROCESS_TEMPERATURE', 'ROTATIONAL_SPEED_RPM', 'TORQUE_NM',
       'TOOL_WEAR_MIN', 'HUMIDITY_RELATIVE_AVG']
result = permutation_importance(
    model, X_test, y_test, n_repeats=10, random_state=42, n_jobs=2
)

forest_importances = pd.Series(result.importances_mean, index=feature_names)
fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=result.importances_std, ax=ax)
ax.set_title("Feature importances using permutation on full model")
ax.set_ylabel("Mean accuracy decrease")
fig.tight_layout()
plt.show()

# %% [markdown]
# # Register training dataset with mlflow runid

# %%
# register dataset
from azureml.core import Workspace, Dataset

# Connect to the Workspace
ws = Workspace.from_config()

# The default datastore is a blob storage container where datasets are stored
datastore = ws.get_default_datastore()

# Register the dataset
ds = Dataset.Tabular.register_pandas_dataframe(
        dataframe=maintenance_hum_df, 
        name=run.info.run_id+'maintenance_hum_df', 
        description='maintenance df for model training',
        target=datastore
    )

# %%
client = mlflow.tracking.MlflowClient()
client.list_artifacts(run_id=run.info.run_id)

# %% [markdown]
# # Register Model

# %%
import os
mlflow.sklearn.save_model(model, "./maint")
model_local_path = os.path.abspath("./maint")
mlflow.register_model(f"file://{model_local_path}", "maint-model")

# %% [markdown]
# # Deploy Model to snowflake

# %%
from azureml.core import Model
model_path = Model.get_model_path(model_name = 'maint', version = 1, _workspace= ws)
model_path

# %%
# Load model
from joblib import load
aml_model = load(model_path + "/model.pkl")
aml_model

# %%
# deploy to registry
from snowflake.ml.registry import registry
from snowflake.snowpark.functions import *
from snowflake.snowpark.types import *

reg = registry.Registry(session=session)
sample_df = maintenance_hum_df.drop("MACHINE_FAILURE", axis = 1)
reg.log_model(aml_model, model_name='aml_model', version_name='v1', sample_input_data=sample_df)

# verify model deployment and view functions associated with the model
mv = reg.get_model('aml_model').version('v1')
mv.show_functions()

# %%
# run the below sql in snowflake
# -- test function
# use role accountadmin;
# select GET(aml_model!predict_proba(AIR_TEMPERATURE_K,
#       PROCESS_TEMPERATURE, ROTATIONAL_SPEED_RPM, TORQUE_NM,
#       TOOL_WEAR_MIN, HUMIDITY_RELATIVE_AVG), 'output_feature_1') as predicted_failure, * from maintenance_hum;
